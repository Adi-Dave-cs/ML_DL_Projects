# %%
# !pip install requests

# %%
# !pip install -q --upgrade transformers==4.56.2

# %%
# Let's check the GPU - it should be a Tesla T4

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
  if gpu_info.find('Tesla T4') >= 0:
    print("Success - Connected to a T4")
  else:
    print("NOT CONNECTED TO A T4")

# %%
from urllib.parse import uses_fragment
from huggingface_hub import login
from google.colab import userdata

hf_token = userdata.get('HF_TOKEN')
login(hf_token,add_to_git_credential=True)

# %%
from IPython.display import display
from diffusers import AutoPipelineForText2Image
import torch

pipe = AutoPipelineForText2Image.from_pretrained("stabilityai/sdxl-turbo", torch_dtype=torch.float16, variant="fp16")
pipe.to("cuda")
prompt = "A corporate executive learning AI engineering in a vibrant pop-art style"
image = pipe(prompt=prompt, num_inference_steps=4, guidance_scale=0.0).images[0]
display(image)

# %%
# Restart the kernel

import IPython
IPython.Application.instance().kernel.do_shutdown(True)

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         113G   39G   75G  34% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  750M  62% /usr/sbin/docker-init
# tmpfs           6.4G   76K  6.4G   1% /var/colab
# /dev/sda1        74G   41G   34G  56% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !rm -rf /content/drive/MyDrive/.Trash/*

# %%
# !rm -rf ~/.cache

# %%
# !rm -rf ~/.cache/huggingface
# !rm -rf ~/.cache/transformers

# %%
# !rm -rf /content/*
# !rm -rf ~/.cache
# !pip cache purge
# Out:
# WARNING: No matching packages
# Files removed: 0

# %%
# !du -h / | sort -rh | head -30
# Out:
# du: cannot read directory '/proc/66/task/66/net': Invalid argument
# du: cannot read directory '/proc/66/net': Invalid argument
# du: cannot access '/proc/1239/task/1239/fd/4': No such file or directory
# du: cannot access '/proc/1239/task/1239/fdinfo/4': No such file or directory
# du: cannot access '/proc/1239/fd/3': No such file or directory
# du: cannot access '/proc/1239/fdinfo/3': No such file or directory
# 38G	/
# 31G	/usr
# 24G	/usr/local
# 19G	/usr/local/lib
# 18G	/usr/local/lib/python3.12/dist-packages
# 18G	/usr/local/lib/python3.12
# 4.9G	/usr/lib
# 4.8G	/usr/local/cuda-12.5
# 4.3G	/usr/local/cuda-12.5/targets/x86_64-linux/lib
# 4.3G	/usr/local/cuda-12.5/targets/x86_64-linux
# 4.3G	/usr/local/cuda-12.5/targets
# 4.1G	/usr/lib/x86_64-linux-gnu
# 4.1G	/root
# 4.0G	/root/.julia
# 3.7G	/usr/local/lib/python3.12/dist-packages/nvidia
# 2.5G	/root/.julia/artifacts
# 2.1G	/usr/local/lib/python3.12/dist-packages/libcugraph/lib64
# 2.1G	/usr/local/lib/python3.12/dist-packages/libcugraph
# 1.8G	/usr/local/lib/python3.12/dist-packages/tensorflow
# 1.7G	/tools
# 1.6G	/usr/local/lib/python3.12/dist-packages/torch
# 1.5G	/usr/local/lib/python3.12/dist-packages/torch/lib
# 1.3G	/opt
# 1.2G	/tools/google-cloud-sdk
# 1.2G	/root/.julia/compiled/v1.11
# 1.2G	/root/.julia/compiled
# 1.2G	/opt/nvidia/nsight-compute/2024.2.1
# 1.2G	/opt/nvidia/nsight-compute
# 1.2G	/opt/nvidia
# 1005M	/usr/local/lib/python3.12/dist-packages/nvidia/cudnn/lib

# %%
# !rm -rf /root/.julia

# %%
from google.colab import userdata
from huggingface_hub import login
from transformers import AutoTokenizer

# %%
# Log in to Hugging Face

hf_token = userdata.get('HF_TOKEN')
if hf_token and hf_token.startswith("hf_"):
  print("HF key looks good so far")
else:
  print("HF key is not set - please click the key in the left sidebar")
login(hf_token, add_to_git_credential=True)

# Check Google Colab GPU

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
  if gpu_info.find('Tesla T4') >= 0:
    print("Success - Connected to a T4")
  else:
    print("NOT CONNECTED TO A T4")
# Out:
# HF key looks good so far
# Wed Nov 19 17:03:11 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# Success - Connected to a T4

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Tell a light-hearted joke for a room of Data Scientists"}
  ]

# %%
PHI4 = "microsoft/Phi-4-mini-instruct"
DEEPSEEK = "deepseek-ai/DeepSeek-V3.1"
QWEN_CODER = "Qwen/Qwen2.5-Coder-7B-Instruct"

# %%
phi4_tokenizer = AutoTokenizer.from_pretrained(PHI4)

text = "I am curiously excited to show Hugging Face Tokenizers in action to my LLM engineers"
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/15.5M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/249 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/587 [00:00<?, ?B/s]

# %%
print("\nPhi 4:")
tokens = phi4_tokenizer.encode(text)
print(tokens)
print(phi4_tokenizer.batch_decode(tokens))
# Out:
# Phi 4:
# [40, 939, 4396, 23138, 15209, 316, 2356, 59116, 4512, 29049, 17951, 24223, 306, 3736, 316, 922, 451, 19641, 32437]
# ['I', ' am', ' cur', 'iously', ' excited', ' to', ' show', ' Hug', 'ging', ' Face', ' Token', 'izers', ' in', ' action', ' to', ' my', ' L', 'LM', ' engineers']

# %%
print("\nPhi 4:")
print(phi4_tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True))
# Out:
# Phi 4:
# <|system|>You are a helpful assistant<|end|><|user|>Tell a light-hearted joke for a room of Data Scientists<|end|><|assistant|>

# %%
deepseek_tokenizer = AutoTokenizer.from_pretrained(DEEPSEEK)

text = "I am curiously excited to show Hugging Face Tokenizers in action to my LLM engineers"
print()
print(phi4_tokenizer.encode(text))
print()
print(deepseek_tokenizer.encode(text))
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# [40, 939, 4396, 23138, 15209, 316, 2356, 59116, 4512, 29049, 17951, 24223, 306, 3736, 316, 922, 451, 19641, 32437]
#
# [0, 43, 1030, 108771, 15046, 304, 1801, 24133, 5426, 11906, 47948, 24524, 295, 4271, 304, 1026, 33792, 47, 26170]

# %%
print("\nPhi:")
print(phi4_tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True))
print("\nDeepSeek:")
print(deepseek_tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True))
# Out:
# Phi:
# <|system|>You are a helpful assistant<|end|><|user|>Tell a light-hearted joke for a room of Data Scientists<|end|><|assistant|>
#
# DeepSeek:
# <｜begin▁of▁sentence｜>You are a helpful assistant<｜User｜>Tell a light-hearted joke for a room of Data Scientists<｜Assistant｜></think>

# %%
qwen_tokenizer = AutoTokenizer.from_pretrained(QWEN_CODER)
code = """
def hello_world(person):
  print("Hello", person)
"""
tokens = qwen_tokenizer.encode(code)
for token in tokens:
  print(f"{token}={qwen_tokenizer.decode(token)}")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# 198=
#
# 750=def
# 23811= hello
# 31792=_world
# 29766=(person
# 982=):
#
# 220=
# 1173= print
# 445=("
# 9707=Hello
# 497=",
# 1697= person
# 340=)
